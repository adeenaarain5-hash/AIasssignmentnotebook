# %% [markdown]
# ## AI Assignment Adeena Arain
# 2312143  BSCS-6(B)
#
# Repository link: https://github.com/adeenaarain5-hash/AIasssignmentnotebook

# %%
import pandas as pd
df = pd.read_csv("Pakistan Largest Ecommerce Dataset.csv")
df.head()
# Out:
#    item_id          status created_at  \
# 0   211131        complete   7/1/2016
# 1   211133        canceled   7/1/2016
# 2   211134        canceled   7/1/2016
# 3   211135        complete   7/1/2016
# 4   211136  order_refunded   7/1/2016
#
#                                                  sku   price  qty_ordered  \
# 0                                  kreations_YI 06-L  1950.0            1
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...   240.0            1
# 2                                 Ego_UP0017-999-MR0  2450.0            1
# 3                                     kcc_krone deal   360.0            1
# 4                                        BK7010400AG   555.0            2
#
#    grand_total  increment_id    category_name_1 sales_commission_code  ...  \
# 0       1950.0     100147443    Women's Fashion                    \N  ...
# 1        240.0     100147444  Beauty & Grooming                    \N  ...
# 2       2450.0     100147445    Women's Fashion                    \N  ...
# 3         60.0     100147446  Beauty & Grooming           R-FSD-52352  ...
# 4       1110.0     100147447            Soghaat                    \N  ...
#
#    Month Customer Since     M-Y    FY Customer ID  Unnamed: 21  Unnamed: 22  \
# 0      7         2016-7  7-2016  FY17         1.0          NaN          NaN
# 1      7         2016-7  7-2016  FY17         2.0          NaN          NaN
# 2      7         2016-7  7-2016  FY17         3.0          NaN          NaN
# 3      7         2016-7  7-2016  FY17         4.0          NaN          NaN
# 4      7         2016-7  7-2016  FY17         5.0          NaN          NaN
#
#   Unnamed: 23 Unnamed: 24 Unnamed: 25
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['item_id', 'status', 'created_at', 'sku', 'price', 'qty_ordered',
#        'grand_total', 'increment_id', 'category_name_1',
#        'sales_commission_code', 'discount_amount', 'payment_method',
#        'Working Date', 'BI Status', ' MV ', 'Year', 'Month', 'Customer Since',
#        'M-Y', 'FY', 'Customer ID', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %%
#Removing unnecessary columns, if present.
df = df.drop(columns=['Unnamed: 0'], errors='ignore')

# %%
#Handles all null values
df.isnull().sum()
# Out:
# item_id                      0
# status                       0
# created_at                   0
# sku                          5
# price                        0
# qty_ordered                  0
# grand_total                  0
# increment_id                 0
# category_name_1              0
# sales_commission_code        0
# discount_amount              0
# payment_method               0
# Working Date                 0
# BI Status                    0
#  MV                          0
# Year                         0
# Month                        0
# Customer Since               0
# M-Y                          0
# FY                           0
# Customer ID                  1
# Unnamed: 21              46447
# Unnamed: 22              46447
# Unnamed: 23              46447
# Unnamed: 24              46447
# Unnamed: 25              46447
# dtype: int64

# %%
#Handle duplicates: if any remove them
df = df.drop_duplicates()

# %%
#Fill null values with 0
df = df.fillna(0)

# %%
import pandas as pd
ad = pd.read_csv("Pakistan Largest Ecommerce Dataset.csv")
ad.head()
# Out:
#    item_id          status created_at  \
# 0   211131        complete   7/1/2016
# 1   211133        canceled   7/1/2016
# 2   211134        canceled   7/1/2016
# 3   211135        complete   7/1/2016
# 4   211136  order_refunded   7/1/2016
#
#                                                  sku   price  qty_ordered  \
# 0                                  kreations_YI 06-L  1950.0            1
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...   240.0            1
# 2                                 Ego_UP0017-999-MR0  2450.0            1
# 3                                     kcc_krone deal   360.0            1
# 4                                        BK7010400AG   555.0            2
#
#    grand_total  increment_id    category_name_1 sales_commission_code  ...  \
# 0       1950.0     100147443    Women's Fashion                    \N  ...
# 1        240.0     100147444  Beauty & Grooming                    \N  ...
# 2       2450.0     100147445    Women's Fashion                    \N  ...
# 3         60.0     100147446  Beauty & Grooming           R-FSD-52352  ...
# 4       1110.0     100147447            Soghaat                    \N  ...
#
#    Month Customer Since     M-Y    FY Customer ID  Unnamed: 21  Unnamed: 22  \
# 0      7         2016-7  7-2016  FY17         1.0          NaN          NaN
# 1      7         2016-7  7-2016  FY17         2.0          NaN          NaN
# 2      7         2016-7  7-2016  FY17         3.0          NaN          NaN
# 3      7         2016-7  7-2016  FY17         4.0          NaN          NaN
# 4      7         2016-7  7-2016  FY17         5.0          NaN          NaN
#
#   Unnamed: 23 Unnamed: 24 Unnamed: 25
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
#
# [5 rows x 26 columns]

# %%
df = pd.read_csv("Pakistan Largest Ecommerce Dataset.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Find Correlations
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numeric columns for correlation
numeric_df = df.select_dtypes(include=['number'])
correlation = numeric_df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(correlation, annot=True)
plt.show()

# %%
#Find most important features for grand_total
correlation['grand_total'].sort_values(ascending=False)
# Out:
# grand_total        1.000000
# price              0.649864
# discount_amount    0.107287
# qty_ordered        0.086400
# Customer ID        0.084609
# item_id            0.046563
# increment_id       0.046161
# Month              0.039708
# Year                    NaN
# Unnamed: 21             NaN
# Unnamed: 22             NaN
# Unnamed: 23             NaN
# Unnamed: 24             NaN
# Unnamed: 25             NaN
# Name: grand_total, dtype: float64

# %%
#Scatter Plot of Important Features
plt.scatter(df['qty_ordered'], df['grand_total'])
plt.xlabel("Quantity Ordered")
plt.ylabel("Grand Total")
plt.show()

# %%
#Handling outliers
import numpy as np

Q1 = df['grand_total'].quantile(0.25)
Q3 = df['grand_total'].quantile(0.75)

IQR = Q3 - Q1

df = df[(df['grand_total'] >= Q1 - 1.5*IQR) & (df['grand_total'] <= Q3 + 1.5*IQR)]

# %% [markdown]
# Q:
# What is the best-selling category?
# A:
# The best-selling category is the one with the highest number of orders in the dataset. By analyzing the frequency of the category_name_1 column, we can determine which category has the most sales.
# The category with the highest count represents the most popular products among customers

# %%
df['category_name_1'].value_counts()
# Out:
# category_name_1
# Soghaat               7603
# Beauty & Grooming     6698
# Men's Fashion         5834
# Mobiles & Tablets     3937
# Women's Fashion       2458
# Home & Living         1945
# Superstore            1455
# Kids & Baby           1448
# Appliances            1430
# Health & Sports       1410
# \N                    1291
# Computing              889
# School & Education     636
# Entertainment          636
# Others                 483
# Books                  283
# Name: count, dtype: int64

# %%
df['category_name_1'].value_counts().plot(kind='bar')
plt.title("Best Selling Category")
plt.show()

# %%
#Find a correlation between payment method and order status
df['payment_method'].value_counts().plot(kind='bar')
plt.title("Payment Method Frequency")
plt.show()

# %%
df['status'].value_counts().plot(kind='bar')
plt.title("Order Status Frequency")
plt.show()

# %%
pd.crosstab(df['payment_method'], df['status'])
# Out:
# status             canceled  closed  complete  holded  order_refunded  \
# payment_method
# Payaxis                4343       7      1819       0              83
# cashatdoorstep            4       0       605       0              26
# cod                    2451      94     21478       6            4607
# customercredit            6      11       336       0              64
# financesettlement         0       0         0       0               1
# internetbanking         123       4        89       0               8
# marketingexpense          0       0        34       0               1
# mcblite                 106       0       187       0               4
# mygateway               267       0         5       0               2
# productcredit            10       2        81       0              15
# ublcreditcard           291       0       120       0              14
#
# status             received  refund
# payment_method
# Payaxis                   6      76
# cashatdoorstep            0      16
# cod                     100     852
# customercredit            3      38
# financesettlement         0       0
# internetbanking           0       6
# marketingexpense          0       0
# mcblite                   0       6
# mygateway                 0       0
# productcredit             0      15
# ublcreditcard             6       8

# %%
#Correlation Between Order Date & Category
df['created_at'] = pd.to_datetime(df['created_at'])

df.groupby(df['created_at'].dt.month)['category_name_1'].value_counts()
# Out:
# created_at  category_name_1
# 7           Beauty & Grooming    2384
#             Soghaat              1677
#             Men's Fashion         907
#             \N                    698
#             Women's Fashion       401
#                                  ...
# 10          \N                    149
#             Computing             104
#             Others                 88
#             Books                  66
#             Entertainment          44
# Name: count, Length: 64, dtype: int64

# %%
# Find any hidden patterns that are counter-intuitive for a layman
sns.boxplot(x='payment_method', y='grand_total', data=df)
plt.show()
